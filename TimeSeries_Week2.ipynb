# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet
import matplotlib.pyplot as plt
from fbprophet.plot import add_changepoints_to_plot

# %%
import requests

POLONIEX_OHLCV_BASEURL = 'https://poloniex.com/public?command=returnChartData&currencyPair='

"""
https://poloniex.com/public?command=returnChartData&currencyPair=BTC_POT&start=1435699200&end=9999999999&period=14400

"""

def get_ohlcv_poloniex(pair='BTC_ETH', start=1435699200, end=9999999999, period=900):
    """
    returns ohlcv data for poloniex as pandas dataframe
    convert to unix timestamp using https://coderstoolbox.net/unixtimestamp/
    :param pair: str pair on poloniex
    :param start: int unix timestamp of beginning time
    :param end: int unix timestamp of ending time
    :param period: int candle width in seconds
    :return: pandas df of ohlcv data from poloniex for specified pair, times, and period
    """
    query = POLONIEX_OHLCV_BASEURL + pair + '&start=' + str(start) + '&end=' + str(end) + '&period=' + str(period)
    resp = requests.get(query,verify=False)

    if resp.status_code != 200:
        raise requests.ApiError('GET /tasks/ {}'.format(resp.status_code))

    return pd.DataFrame(resp.json())

# %%
df = get_ohlcv_poloniex(pair='USDT_BTC', start=1483600958, end=9999999999, period=900)
#no option to pass in 3600 sec candles
df = df[df.index % 4 == 0]
df['ds'] = pd.to_datetime(df['date'], unit='s')
df['y'] = df['volume']
df['logVolume'] = df['volume'].apply(np.log)
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
df
# Out:
#              close        date         high          low         open  \
# 0      1143.999999  1483601400  1145.000000  1135.000000  1137.020000
# 4      1136.000000  1483605000  1136.000000  1124.018000  1124.500000
# 8      1092.000000  1483608600  1099.232465  1055.291200  1085.000000
# 12     1086.000000  1483612200  1111.000000  1085.000000  1096.000000
# 16     1099.593509  1483615800  1100.000000  1087.000000  1087.000000
# 20     1025.000000  1483619400  1073.460000  1022.300000  1070.238834
# 24      940.000000  1483623000   990.000000   935.000000   973.000000
# 28      952.890000  1483626600   968.000000   949.990000   953.000000
# 32      993.337000  1483630200   993.337000   972.010001   983.337000
# 36      953.360966  1483633800   973.060000   940.338000   973.060000
# 40      962.022148  1483637400   966.989999   950.000000   957.500798
# 44      975.254010  1483641000   977.911173   971.770005   977.911173
# 48      958.000580  1483644600   963.700000   953.000000   953.941114
# 52      967.064786  1483648200   977.999990   958.787000   959.000000
# 56      962.990000  1483651800   968.044188   956.107403   964.199999
# 60      994.990000  1483655400   995.000000   984.980000   988.000000
# 64      999.990000  1483659000  1000.705769   983.965627   989.000000
# 68     1004.720121  1483662600  1007.568871  1001.010000  1002.623156
# 72     1018.345597  1483666200  1018.345597  1012.144670  1017.000000
# 76      977.006843  1483669800   998.011000   965.231503   989.300000
# 80      980.000000  1483673400   980.000000   960.767162   961.737928
# 84      974.790000  1483677000   975.390000   970.000000   972.748443
# 88      984.990000  1483680600   985.010000   971.000000   971.000000
# 92      975.899989  1483684200   979.945756   973.592219   978.000000
# 96      963.048871  1483687800   975.000000   937.913000   943.000000
# 100     944.100000  1483691400   951.681970   942.100000   950.000000
# 104     919.000000  1483695000   939.675789   919.000000   938.000000
# 108     937.800000  1483698600   940.000000   921.562999   927.081990
# 112     881.000000  1483702200   898.661374   870.000000   896.490144
# 116     889.000000  1483705800   890.100000   878.000001   879.000000
# ...            ...         ...          ...          ...          ...
# 59196  6489.747302  1536877800  6500.000000  6489.383660  6493.490010
# 59200  6490.000000  1536881400  6505.000000  6479.900000  6505.000000
# 59204  6466.187760  1536885000  6472.702401  6460.971844  6464.395354
# 88      36854.282164  10.514727
# 92       3432.479748   8.141038
# 96     104432.303833  11.556294
# 100     37165.850773  10.523146
# 104    151820.642741  11.930455
# 108     63134.940163  11.053030
# 112    369433.794863  12.819727
# 116     68528.162645  11.135000
# ...              ...        ...
# 59196   44133.602697  10.694977
# 59200   80697.388871  11.298461
# 59204   19336.807505   9.869766
# 59208   22979.430839  10.042355
# 59212  100182.356056  11.514747
# 59216   86285.787908  11.365420
# 59220    2868.051644   7.961388
# 59224    1746.377483   7.465299
# 59228    3136.109889   8.050738
# 59232  120597.608078  11.700215
# 59236   45141.132984  10.717549
# 59240  117142.835001  11.671149
# 59244   53998.886031  10.896719
# 59248   22223.356882  10.008899
# 59252   37713.413054  10.537771
# 59256   57418.126102  10.958115
# 59260   81439.301288  11.307613
# 59264   31482.635911  10.357191
# 59268   62056.840252  11.035806
# 59272   33568.719949  10.421350
# 59276   25642.049273  10.151989
# 59280   45999.929249  10.736395
# 59284    9770.033791   9.187075
# 59288    5975.152671   8.695365
# 59292   46632.084218  10.750044
# 59296   79013.959540  11.277380
# 59300    9734.482246   9.183430
# 59304   14096.209261   9.553661
# 59308   14963.923474   9.613397
# 59312    7404.132178   8.909794
#
# [14829 rows x 11 columns]

# %%
df.plot(x='ds', y ='volume')

# %%
df.plot(x='ds', y ='logVolume')

# %% [markdown]
# # Start of Prophet Work

# %%
prophet = Prophet()
prophet.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
df.y.kurtosis()
#The kurtosis is less than 3, which means there are very few outliers than there are in a normal distribution
# Out:
# 78.63342197716841

# %%
df.y.skew()
#The skew is positive, which means that that the the graph is asymmetric, 
#with a longer right tail and the mass on the left side.
# Out:
# 6.339923703636469

# %% [markdown]
# # Creating Future and Forecast with 30 periods, then the volume is plotted with prophet

# %%
#Build future, periods set to 30 because there are 30 days of data
future = prophet.make_future_dataframe(periods=30)
#Build Forecast
forecast = prophet.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                        ds          yhat     yhat_lower     yhat_upper
# 14854 2018-10-11 03:30:00  29458.173376 -639300.691983  682804.535920
# 14855 2018-10-12 03:30:00  49861.117936 -613452.956293  751949.940044
# 14856 2018-10-13 03:30:00 -14301.096684 -634988.502835  716413.895221
# 14857 2018-10-14 03:30:00 -49757.420979 -739292.988928  600294.647661
# 14858 2018-10-15 03:30:00 -33604.353405 -728677.964854  665145.434703

# %%
#Build the plot to show the forecasted data
bc_Volume = prophet.plot(forecast)
a = add_changepoints_to_plot(bc_Volume.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)

# %% [markdown]
# # Daily Forecasts by plotting prophet components future uncertainty

# %%
fig2 = prophet.plot_components(forecast,uncertainty=False)

# %% [markdown]
# # Build the prophet graph of volume data with a changepoint scale of .5; this makes the plotting more flexible

# %%
#Making the plotting more flexible (Alters the graph quite a bit, actually trends upwards instead of down)
m = Prophet(changepoint_prior_scale=0.5)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
df['cap'] = 2500
df['floor'] = 20000
bc_Volume_Logistic = Prophet(growth = 'logistic')
bc_Volume_Logistic.fit(df)
future_logistic = bc_Volume_Logistic.make_future_dataframe(periods=30)
future_logistic['cap'] = 2500
future_logistic['floor'] = 20000
fcst_logistic = bc_Volume_Logistic.predict(future_logistic)
fig_logistic = bc_Volume_Logistic.plot(fcst_logistic)
plt.legend(loc='best', fontsize=20)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
#Build future, periods set to 30 because there are 30 days of data
future = prophet.make_future_dataframe(periods=3)
#Build Forecast
forecast = prophet.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

#Build the plot to show the forecasted data
bc_Volume = prophet.plot(forecast)
a = add_changepoints_to_plot(bc_Volume.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)

# %%
#Build future, periods set to 30 because there are 30 days of data
future = prophet.make_future_dataframe(periods=15)
#Build Forecast
forecast = prophet.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

#Build the plot to show the forecasted data
bc_Volume = prophet.plot(forecast)
a = add_changepoints_to_plot(bc_Volume.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)

# %%
#Build future, periods set to 30 because there are 30 days of data
future = prophet.make_future_dataframe(periods=23)
#Build Forecast
forecast = prophet.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

#Build the plot to show the forecasted data
bc_Volume = prophet.plot(forecast)
a = add_changepoints_to_plot(bc_Volume.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)

# %% [markdown]
# # Deeper Weekly Analysis (Novermber 2017 - March 2018)

# %%
df2 = df.loc[30000:40000]

# %%
df2.plot(x='ds', y ='logVolume')

# %%
df2.plot(x='ds', y ='volume')

# %%
prophet = Prophet()
prophet.fit(df2)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
#Build future, periods set to 30 because there are 30 days of data
future = prophet.make_future_dataframe(periods=30)
#Build Forecast
forecast = prophet.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds           yhat    yhat_lower    yhat_upper
# 2526 2018-03-23 23:30:00  -32265.977030 -1.435731e+06  1.374112e+06
# 2527 2018-03-24 23:30:00 -175984.897036 -1.430459e+06  1.166200e+06
# 2528 2018-03-25 23:30:00 -117429.499605 -1.403439e+06  1.262763e+06
# 2529 2018-03-26 23:30:00 -160528.050902 -1.552457e+06  1.311452e+06
# 2530 2018-03-27 23:30:00  145619.518950 -1.262466e+06  1.501167e+06

# %%
#Build the plot to show the forecasted data
bc_Volume = prophet.plot(forecast)
a = add_changepoints_to_plot(bc_Volume.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)

# %%
fig2 = prophet.plot_components(forecast,uncertainty=False)

# %% [markdown]
# # Deeper Weekly Analysis (June - October)

# %%
df = get_ohlcv_poloniex(pair='USDT_BTC', start=1483600958, end=9999999999, period=900)
#no option to pass in 3600 sec candles
df = df[df.index % 4 == 0]
df['ds'] = pd.to_datetime(df['date'], unit='s')
df['y'] = df['weightedAverage']
df['logVolume'] = df['volume'].apply(np.log)
df3 = df.loc[50000:60000]
# Out:
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
df3.plot(x='ds', y ='logVolume')

# %%
df3.plot(x='ds', y ='volume')

# %%
prophet = Prophet()
prophet.fit(df3)

#Build future, periods set to 30 because there are 30 days of data
future = prophet.make_future_dataframe(periods=30)
#Build Forecast
forecast = prophet.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
#                       ds         yhat   yhat_lower    yhat_upper
# 2354 2018-10-11 03:30:00  5439.990342  1314.762948   9723.116795
# 2355 2018-10-12 03:30:00  5376.373279   905.704290   9981.124217
# 2356 2018-10-13 03:30:00  5325.710070   690.956357  10186.392709
# 2357 2018-10-14 03:30:00  5283.522077   582.728381  10392.681805
# 2358 2018-10-15 03:30:00  5281.593475   375.431283  10691.188316

# %%
#Build the plot to show the forecasted data
bc_Volume = prophet.plot(forecast)
a = add_changepoints_to_plot(bc_Volume.gca(), prophet, forecast)
plt.legend(loc='best', fontsize=20)

# %%
#Here we can see that the volume in the future may either increase greatly or decrease lately, 
#though the trend is a bit downlward.

# %%
fig2 = prophet.plot_components(forecast,uncertainty=False)
